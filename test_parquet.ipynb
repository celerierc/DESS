# %%
import pandas as pd
import numpy as np
import pyarrow as pa
from stats import *

# %%
df = pd.read_parquet('uncomplete.parquet',engine='pyarrow')
get_chunk_processing_stats(df)
# Out:
#                                 Progress Summary
# Processed Chunks    Total Chunks        Percentage (%)      Overall Conversion Rate (%)
# 434                 867                 50.06               49.91
#                                                  id_text             id_name  \
# 86795                   Kathleen Mccormick suny cortland  Kathleen Mccormick
# 86796  Kathleen Mccoy arizona state university campus...      Kathleen Mccoy
# 86797  Kathleen Mcdermott university of california-be...  Kathleen Mcdermott
# 86798                Kathleen Mcdonough suny at fredonia  Kathleen Mcdonough
# 86799  Kathleen Mcdowell university of illinois urban...   Kathleen Mcdowell
# 86800  Kathleen Mcgarry university of california-berk...    Kathleen Mcgarry
# 86801  Kathleen Mchale southern illinois university-c...     Kathleen Mchale
# 86802  Kathleen Mchugh university of california-berkeley     Kathleen Mchugh
# ...

# %%
df = pd.read_parquet('uncomplete.parquet',engine='pyarrow')
df
# Out:
#          fullid                                            id_text  \
# 0          46.0                        A Allaway algoma university
# 1         168.0  A Beckman university of illinois urbana/champaign
# 2         377.0              A Clark university of western ontario
# 3         494.0          A Dunwoody university of british columbia
# 4         525.0   A Endres university of illinois urbana/champaign
# ...         ...                                                ...
# 35038  592006.0               Zvonimir Poljak university of guelph
# 35039  592011.0               Zwart Zwart university of california
# 35040  592018.0               Zwick Zwick university of california
# 35041  592019.0           Zwicker Zwicker university of california
# 35042  592030.0                 Zych Zych university of california
#
#                id_name                            id_university isProfessor  \
# 0            A Allaway                        algoma university        None
# ...
